# %%
import pandas as pd
import re
import tldextract
from urllib.parse import urlparse
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
# Load and prepare data
df = pd.read_csv("dataset_phishing.csv")
df.head(10)
# Out:
#                                                  url  length_url  \
# 0              http://www.crestonwood.com/router.php          37
# 1  http://shadetreetechnology.com/V4/validation/a...          77
# 2  https://support-appleld.com.secureupdate.duila...         126
# 3                                 http://rgipt.ac.in          18
# 4  http://www.iracing.com/tracks/gateway-motorspo...          55
# 5                   http://appleid.apple.com-app.es/          32
# 6                                http://www.mutuo.it          19
# 7  http://www.shadetreetechnology.com/V4/validati...          81
# 8         http://vamoaestudiarmedicina.blogspot.com/          42
# 9  https://parade.com/425836/joshwigler/the-amazi...         104
#
#    length_hostname  ip  nb_dots  nb_hyphens  nb_at  nb_qm  nb_and  nb_or  ...  \
# 0               19   0        3           0      0      0       0      0  ...
# 1               23   1        1           0      0      0       0      0  ...
# ...

# %%
df.isnull().sum()
# Out:
# url                0
# length_url         0
# length_hostname    0
# ip                 0
# nb_dots            0
#                   ..
# web_traffic        0
# dns_record         0
# google_index       0
# page_rank          0
# status             0
# Length: 89, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11430 entries, 0 to 11429
# Data columns (total 89 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   url                         11430 non-null  object
#  1   length_url                  11430 non-null  int64
#  2   length_hostname             11430 non-null  int64
#  3   ip                          11430 non-null  int64
#  4   nb_dots                     11430 non-null  int64
#  5   nb_hyphens                  11430 non-null  int64
#  6   nb_at                       11430 non-null  int64
#  7   nb_qm                       11430 non-null  int64
#  8   nb_and                      11430 non-null  int64
#  9   nb_or                       11430 non-null  int64
#  10  nb_eq                       11430 non-null  int64
#  11  nb_underscore               11430 non-null  int64
#  12  nb_tilde                    11430 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['url', 'length_url', 'length_hostname', 'ip', 'nb_dots', 'nb_hyphens',
#        'nb_at', 'nb_qm', 'nb_and', 'nb_or', 'nb_eq', 'nb_underscore',
#        'nb_tilde', 'nb_percent', 'nb_slash', 'nb_star', 'nb_colon', 'nb_comma',
#        'nb_semicolumn', 'nb_dollar', 'nb_space', 'nb_www', 'nb_com',
#        'nb_dslash', 'http_in_path', 'https_token', 'ratio_digits_url',
#        'ratio_digits_host', 'punycode', 'port', 'tld_in_path',
#        'tld_in_subdomain', 'abnormal_subdomain', 'nb_subdomains',
#        'prefix_suffix', 'random_domain', 'shortening_service',
#        'path_extension', 'nb_redirection', 'nb_external_redirection',
#        'length_words_raw', 'char_repeat', 'shortest_words_raw',
#        'shortest_word_host', 'shortest_word_path', 'longest_words_raw',
#        'longest_word_host', 'longest_word_path', 'avg_words_raw',
#        'avg_word_host', 'avg_word_path', 'phish_hints', 'domain_in_brand',
#        'brand_in_subdomain', 'brand_in_path', 'suspecious_tld',
# ...

# %%
print(df['status'].value_counts())
# Out:
# status
# legitimate    5715
# phishing      5715
# Name: count, dtype: int64

# %%
#drop the data
X = df.drop(["status", "url"], axis=1)
y = df["status"].apply(lambda x: 1 if x == "phishing" else 0)  # Convert to binary

# %%
# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
# Train model with optimized parameters
model = RandomForestClassifier(
    n_estimators=150,
    max_depth=20,
    min_samples_split=5,
    class_weight="balanced",
    random_state=42
)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=20,
#                        min_samples_split=5, n_estimators=150, random_state=42)

# %%
# Evaluation
print("Test Accuracy:", accuracy_score(y_test, model.predict(X_test)))
print(classification_report(y_test, model.predict(X_test)))
# Out:
# Test Accuracy: 0.9610673665791776
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96      1143
#            1       0.96      0.96      0.96      1143
#
#     accuracy                           0.96      2286
#    macro avg       0.96      0.96      0.96      2286
# weighted avg       0.96      0.96      0.96      2286

# %%
def extract_features(url):
    parsed = urlparse(url)
    ext = tldextract.extract(url)
    hostname = parsed.hostname or ''
    path = parsed.path or ''
    
    features = {
        'length_url': len(url),
        'length_hostname': len(hostname),
        'ip': int(bool(re.match(r'^(\d+\.){3}\d+$', hostname))),
        'nb_dots': url.count('.'),
        'nb_hyphens': url.count('-'),
        'nb_at': url.count('@'),
        'nb_qm': url.count('?'),
        'nb_and': url.count('&'),
        'nb_eq': url.count('='),
        'nb_underscore': url.count('_'),
        'nb_slash': url.count('/'),
        'nb_colon': url.count(':'),
        'nb_comma': url.count(','),
        'nb_semicolumn': url.count(';'),
        'nb_dollar': url.count('$'),
        'nb_space': url.count(' '),
        'nb_www': url.lower().count('www'),
        'nb_com': url.lower().count('.com'),
        'nb_dslash': url.count('//'),
        'http_in_path': int('http' in path),
        'https_token': int('https' in url.lower() and not url.lower().startswith('https://')),
        'ratio_digits_url': sum(c.isdigit() for c in url) / max(len(url), 1),
        'ratio_digits_host': sum(c.isdigit() for c in hostname) / max(len(hostname), 1),
        'tld_in_path': int(ext.suffix and ext.suffix in path),
        'tld_in_subdomain': int(ext.suffix and ext.suffix in ext.subdomain),
        'nb_subdomains': len(ext.subdomain.split('.')),
        'prefix_suffix': int('-' in ext.domain),
        'shortening_service': int(any(s in url for s in ['bit.ly', 'goo.gl', 'tinyurl.com'])),
        'longest_word_host': max((len(w) for w in re.split(r'\W+', hostname) if w), default=0),
        'avg_word_host': sum(len(w) for w in re.split(r'\W+', hostname) if w) / max(len(re.split(r'\W+', hostname)), 1),
        'phish_hints': int(any(w in url.lower() for w in ['login', 'secure', 'account', 'verify', 'update']))
    }
    
    # Create DataFrame with same columns as training data
    features_df = pd.DataFrame(columns=X_train.columns)
    for col in features_df.columns:
        features_df[col] = [features.get(col, 0)]  # Use 0 as default for missing features
    
    return features_df

# %%
# Prediction function with adjusted threshold
def check_url(url, threshold=0.6):
    features = extract_features(url)
    prob = model.predict_proba(features)[0][1]  # Probability of being phishing
    
    print(f"\n🔍 URL: {url}")
    if prob > threshold:
        print(f"⚠️  Phishing detected! (Confidence: {prob*100:.1f}%)")
    else:
        print(f"✅ Safe URL. (Confidence: {(1-prob)*100:.1f}%)")

# %%
# Test cases
test_urls = [
    # Phishing examples
    "http://secure-login-paypal.com/account/verify",
    "http://ebay-login-security-check.com/update",
    "http://google.drive-userconfirm.ru/login",
    
    # Legitimate examples
    "https://www.google.com",
    "https://www.amazon.com",
    "https://www.wikipedia.org"
]

print("🔎 Phishing URL Detection Results 🔍")
for url in test_urls:
    check_url(url)
    print("─" * 50)
# Out:
# 🔎 Phishing URL Detection Results 🔍
#
# 🔍 URL: http://secure-login-paypal.com/account/verify
# ⚠️  Phishing detected! (Confidence: 74.0%)
# ──────────────────────────────────────────────────
#
# 🔍 URL: http://ebay-login-security-check.com/update
# ⚠️  Phishing detected! (Confidence: 73.6%)
# ──────────────────────────────────────────────────
#
# 🔍 URL: http://google.drive-userconfirm.ru/login
# ⚠️  Phishing detected! (Confidence: 75.7%)
# ──────────────────────────────────────────────────
#
# 🔍 URL: https://www.google.com
# ✅ Safe URL. (Confidence: 50.8%)
# ──────────────────────────────────────────────────
#
# 🔍 URL: https://www.amazon.com
# ✅ Safe URL. (Confidence: 50.8%)
# ──────────────────────────────────────────────────
#
# 🔍 URL: https://www.wikipedia.org
# ✅ Safe URL. (Confidence: 51.6%)
# ──────────────────────────────────────────────────

# %%
test_urls = [
    # 🧪 Phishing URLs (suspicious)
    "http://secure-login-paypal.com/account/verify",
    "http://ebay-login-security-check.com/update",
    "http://google.drive-userconfirm.ru/login",
    "http://amazon.verification-center.co/signin",
    "http://login-facebook-support.net/security",

    # ✅ Safe URLs (trusted)
    "https://www.google.com",
    "https://www.amazon.in",
    "https://www.facebook.com",
    "https://www.wikipedia.org",
    "https://www.bbc.com/news"
]

print("🔎 Batch Testing URLs...\n")

for url in test_urls:
    print(f"URL: {url}")
    check_url(url)
    print("-" * 50)
# Out:
# 🔎 Batch Testing URLs...
#
# URL: http://secure-login-paypal.com/account/verify
#
# 🔍 URL: http://secure-login-paypal.com/account/verify
# ⚠️  Phishing detected! (Confidence: 74.0%)
# --------------------------------------------------
# URL: http://ebay-login-security-check.com/update
#
# 🔍 URL: http://ebay-login-security-check.com/update
# ⚠️  Phishing detected! (Confidence: 73.6%)
# --------------------------------------------------
# URL: http://google.drive-userconfirm.ru/login
#
# 🔍 URL: http://google.drive-userconfirm.ru/login
# ⚠️  Phishing detected! (Confidence: 75.7%)
# --------------------------------------------------
# URL: http://amazon.verification-center.co/signin
#
# 🔍 URL: http://amazon.verification-center.co/signin
# ⚠️  Phishing detected! (Confidence: 71.4%)
# --------------------------------------------------
# URL: http://login-facebook-support.net/security
#
# 🔍 URL: http://login-facebook-support.net/security
# ⚠️  Phishing detected! (Confidence: 73.8%)
# ...

# %%
test_urls = [
    # 🧪 Phishing URLs (suspicious)
    "http://paypal.secure-login-update.com",

     "http://appleid.apple.com.sign-in.verify-user.com",

     "http://facebook.account-login-verification.com",

     "http://bankofamerica.login-secure.com",

     "http://update.microsoft-support.com.secure-verify.info",

     "http://secure.amazon-account-verification.com",

    "http://netflix-user-login-update.com",

    # ✅ Safe URLs (trusted)
    "https://www.google.com",
    "https://www.amazon.in",
    "https://www.facebook.com",
    "https://www.wikipedia.org",
    "https://www.bbc.com/news"
]

print("🔎 Batch Testing URLs...\n")

for url in test_urls:
    print(f"URL: {url}")
    check_url(url)
    print("-" * 50)
# Out:
# 🔎 Batch Testing URLs...
#
# URL: http://paypal.secure-login-update.com
#
# 🔍 URL: http://paypal.secure-login-update.com
# ⚠️  Phishing detected! (Confidence: 74.0%)
# --------------------------------------------------
# URL: http://appleid.apple.com.sign-in.verify-user.com
#
# 🔍 URL: http://appleid.apple.com.sign-in.verify-user.com
# ⚠️  Phishing detected! (Confidence: 74.7%)
# --------------------------------------------------
# URL: http://facebook.account-login-verification.com
#
# 🔍 URL: http://facebook.account-login-verification.com
# ⚠️  Phishing detected! (Confidence: 74.3%)
# --------------------------------------------------
# URL: http://bankofamerica.login-secure.com
#
# 🔍 URL: http://bankofamerica.login-secure.com
# ⚠️  Phishing detected! (Confidence: 74.1%)
# --------------------------------------------------
# URL: http://update.microsoft-support.com.secure-verify.info
#
# 🔍 URL: http://update.microsoft-support.com.secure-verify.info
# ...

# %%
check_url("http://secure-login.ebay.com/account/update")
check_url("https://www.google.com")
# Out:
# 🔍 URL: http://secure-login.ebay.com/account/update
# ⚠️  Phishing detected! (Confidence: 74.2%)
#
# 🔍 URL: https://www.google.com
# ✅ Safe URL. (Confidence: 50.8%)

# %%
# !pip install flask

# %%
from flask import Flask, request, jsonify, render_template_string
import pandas as pd
import threading
from IPython.display import display, HTML

# Initialize Flask app
app = Flask(__name__)

# Beautiful HTML template with Bootstrap 5 and custom styling
HTML_TEMPLATE = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>SecureScan | Phishing URL Detector</title>
    <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0/dist/css/bootstrap.min.css" rel="stylesheet">
    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap-icons@1.10.0/font/bootstrap-icons.css">
    <style>
        :root {
            --primary-color: #4361ee;
            --secondary-color: #3f37c9;
            --success-color: #4cc9f0;
            --danger-color: #f72585;
            --light-color: #f8f9fa;
            --dark-color: #212529;
        }
        
        body {
            font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
            background-color: #f5f7fa;
            color: #333;
        }
        
        .navbar-brand {
            font-weight: 700;
            font-size: 1.5rem;
        }
        
        .navbar-brand i {
            color: var(--primary-color);
        }
        
        .card {
            border: none;
            border-radius: 15px;
            box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
            overflow: hidden;
            transition: transform 0.3s ease;
        }
        
        .card:hover {
            transform: translateY(-5px);
        }
        
        .card-header {
            background: linear-gradient(135deg, var(--primary-color), var(--secondary-color));
            color: white;
            font-weight: 600;
            padding: 1.5rem;
        }
        
        .form-control {
            border-radius: 10px;
            padding: 12px 15px;
            border: 2px solid #e9ecef;
        }
        
        .form-control:focus {
            border-color: var(--primary-color);
            box-shadow: 0 0 0 0.25rem rgba(67, 97, 238, 0.25);
        }
        
        .btn-primary {
            background-color: var(--primary-color);
            border: none;
            border-radius: 10px;
            padding: 12px;
            font-weight: 600;
            letter-spacing: 0.5px;
            transition: all 0.3s ease;
        }
        
        .btn-primary:hover {
            background-color: var(--secondary-color);
            transform: translateY(-2px);
        }
        
        .result-card {
            border-left: 5px solid;
            border-radius: 10px;
        }
        
        .safe-card {
            border-left-color: var(--success-color);
            background-color: rgba(76, 201, 240, 0.1);
        }
        
        .phishing-card {
            border-left-color: var(--danger-color);
            background-color: rgba(247, 37, 133, 0.1);
        }
        
        .confidence-meter {
            height: 10px;
            border-radius: 5px;
            background: linear-gradient(to right, #4cc9f0, #f72585);
            margin: 10px 0;
            position: relative;
        }
        
        .confidence-indicator {
            position: absolute;
            height: 20px;
            width: 20px;
            background-color: white;
            border-radius: 50%;
            border: 3px solid var(--dark-color);
            top: -5px;
            transform: translateX(-50%);
        }
        
        .feature-badge {
            margin-right: 5px;
            margin-bottom: 5px;
            font-size: 0.8rem;
        }
        
        .footer {
            background-color: var(--dark-color);
            color: white;
            padding: 2rem 0;
            margin-top: 3rem;
        }
        
        .feature-icon {
            font-size: 2rem;
            margin-bottom: 1rem;
            color: var(--primary-color);
        }
        
        .animate-bounce {
            animation: bounce 2s infinite;
        }
        
        @keyframes bounce {
            0%, 100% { transform: translateY(0); }
            50% { transform: translateY(-10px); }
        }
    </style>
</head>
<body>
    <!-- Navigation -->
    <nav class="navbar navbar-expand-lg navbar-dark bg-dark">
        <div class="container">
            <a class="navbar-brand" href="#">
                <i class="bi bi-shield-lock"></i> SecureScan
            </a>
            <button class="navbar-toggler" type="button" data-bs-toggle="collapse" data-bs-target="#navbarNav">
                <span class="navbar-toggler-icon"></span>
            </button>
            <div class="collapse navbar-collapse" id="navbarNav">
                <ul class="navbar-nav ms-auto">
                    <li class="nav-item">
                        <a class="nav-link active" href="#">Home</a>
                    </li>
                    <li class="nav-item">
                        <a class="nav-link" href="#how-it-works">How It Works</a>
                    </li>
                    <li class="nav-item">
                        <a class="nav-link" href="#about">About</a>
                    </li>
                </ul>
            </div>
        </div>
    </nav>

    <!-- Hero Section -->
    <section class="py-5">
        <div class="container">
            <div class="row align-items-center">
                <div class="col-lg-6">
                    <h1 class="display-4 fw-bold mb-4">Protect Yourself From Phishing Attacks</h1>
                    <p class="lead mb-4">Our advanced machine learning model analyzes URLs to detect potential phishing attempts with high accuracy.</p>
                    <div class="d-flex gap-3">
                        <a href="#scan-now" class="btn btn-primary btn-lg px-4">Scan a URL Now</a>
                        <a href="#how-it-works" class="btn btn-outline-dark btn-lg px-4">Learn More</a>
                    </div>
                </div>
                <div class="col-lg-6">
                    <img src="https://illustrations.popsy.co/amber/secure-server.svg" alt="Security illustration" class="img-fluid animate-bounce">
                </div>
            </div>
        </div>
    </section>

    <!-- Main Scanner Section -->
    <section id="scan-now" class="py-5 bg-white">
        <div class="container">
            <div class="row justify-content-center">
                <div class="col-lg-8">
                    <div class="card">
                        <div class="card-header text-center">
                            <h2 class="mb-0"><i class="bi bi-search"></i> URL Scanner</h2>
                        </div>
                        <div class="card-body p-4">
                            <form method="POST">
                                <div class="mb-3">
                                    <label for="url" class="form-label">Enter URL to analyze:</label>
                                    <div class="input-group">
                                        <span class="input-group-text"><i class="bi bi-link-45deg"></i></span>
                                        <input type="text" class="form-control form-control-lg" id="url" name="url" 
                                               placeholder="https://example.com" required>
                                    </div>
                                    <div class="form-text">We'll analyze the URL without storing or visiting it.</div>
                                </div>
                                <button type="submit" class="btn btn-primary w-100 py-3">
                                    <i class="bi bi-shield-check"></i> Analyze URL
                                </button>
                            </form>
                            
                            {% if result %}
                            <div class="mt-4 result-card p-4 {{ 'safe-card' if result.is_safe else 'phishing-card' }}">
                                <div class="d-flex align-items-center mb-3">
                                    <div class="me-3">
                                        {% if result.is_safe %}
                                        <i class="bi bi-check-circle-fill text-success" style="font-size: 2rem;"></i>
                                        {% else %}
                                        <i class="bi bi-exclamation-triangle-fill text-danger" style="font-size: 2rem;"></i>
                                        {% endif %}
                                    </div>
                                    <div>
                                        <h3 class="mb-0">{{ result.status }}</h3>
                                        <p class="mb-0 text-muted">{{ result.url }}</p>
                                    </div>
                                </div>
                                
                                <div class="mb-3">
                                    <div class="d-flex justify-content-between mb-1">
                                        <span>Risk Level</span>
                                        <span>{{ result.confidence }}% confidence</span>
                                    </div>
                                    <div class="confidence-meter">
                                        <div class="confidence-indicator" style="left: {{ result.confidence }}%;"></div>
                                    </div>
                                </div>
                                
                                <div class="alert {{ 'alert-success' if result.is_safe else 'alert-danger' }}">
                                    <i class="bi {{ 'bi-info-circle-fill' if result.is_safe else 'bi-exclamation-octagon-fill' }} me-2"></i>
                                    {{ result.details }}
                                </div>
                                
                                {% if result.key_features %}
                                <div class="mt-3">
                                    <h5><i class="bi bi-list-check"></i> Key Features Analyzed:</h5>
                                    <div class="d-flex flex-wrap mt-2">
                                        {% for feature in result.key_features %}
                                        <span class="badge feature-badge {{ 'bg-success' if feature.safe else 'bg-danger' }}">
                                            <i class="bi {{ 'bi-check-circle' if feature.safe else 'bi-exclamation-triangle' }} me-1"></i>
                                            {{ feature.name }}: {{ feature.value }}
                                        </span>
                                        {% endfor %}
                                    </div>
                                </div>
                                {% endif %}
                            </div>
                            {% endif %}
                        </div>
                    </div>
                </div>
            </div>
        </div>
    </section>

    <!-- How It Works Section -->
    <section id="how-it-works" class="py-5 bg-light">
        <div class="container">
            <div class="text-center mb-5">
                <h2 class="fw-bold">How Our Phishing Detector Works</h2>
                <p class="lead text-muted">Using advanced machine learning to protect you from online threats</p>
            </div>
            <div class="row g-4">
                <div class="col-md-4">
                    <div class="card h-100 border-0 text-center p-4">
                        <div class="feature-icon">
                            <i class="bi bi-diagram-3"></i>
                        </div>
                        <h3>Feature Extraction</h3>
                        <p>We analyze over 80 different URL characteristics including domain information, special characters, and patterns.</p>
                    </div>
                </div>
                <div class="col-md-4">
                    <div class="card h-100 border-0 text-center p-4">
                        <div class="feature-icon">
                            <i class="bi bi-cpu"></i>
                        </div>
                        <h3>Machine Learning</h3>
                        <p>Our Random Forest model evaluates the extracted features with 96% accuracy based on thousands of examples.</p>
                    </div>
                </div>
                <div class="col-md-4">
                    <div class="card h-100 border-0 text-center p-4">
                        <div class="feature-icon">
                            <i class="bi bi-shield-check"></i>
                        </div>
                        <h3>Instant Results</h3>
                        <p>Get immediate feedback about potential phishing attempts without visiting suspicious sites.</p>
                    </div>
                </div>
            </div>
        </div>
    </section>

    <!-- About Section -->
    <section id="about" class="py-5">
        <div class="container">
            <div class="row align-items-center">
                <div class="col-lg-6">
                    <img src="https://illustrations.popsy.co/amber/security.svg" alt="About security" class="img-fluid">
                </div>
                <div class="col-lg-6">
                    <h2 class="fw-bold mb-4">About SecureScan</h2>
                    <p>SecureScan is a phishing URL detection system developed using machine learning techniques. Our model has been trained on thousands of legitimate and phishing URLs to provide accurate results.</p>
                    <p>This tool is designed to help users identify potentially dangerous websites before interacting with them, protecting against credential theft, malware, and other online threats.</p>
                    <div class="mt-4">
                        <a href="#scan-now" class="btn btn-primary px-4">
                            <i class="bi bi-shield-check"></i> Try It Now
                        </a>
                    </div>
                </div>
            </div>
        </div>
    </section>

    <!-- Footer -->
    <footer class="footer">
        <div class="container">
            <div class="row">
                <div class="col-md-6">
                    <h5><i class="bi bi-shield-lock"></i> SecureScan</h5>
                    <p>Protecting users from phishing attacks with machine learning.</p>
                </div>
                <div class="col-md-3">
                    <h5>Quick Links</h5>
                    <ul class="list-unstyled">
                        <li><a href="#scan-now" class="text-white">Scanner</a></li>
                        <li><a href="#how-it-works" class="text-white">How It Works</a></li>
                        <li><a href="#about" class="text-white">About</a></li>
                    </ul>
                </div>
                <div class="col-md-3">
                    <h5>Connect</h5>
                    <ul class="list-unstyled">
                        <li><a href="#" class="text-white"><i class="bi bi-github"></i> GitHub</a></li>
                        <li><a href="#" class="text-white"><i class="bi bi-twitter"></i> Twitter</a></li>
                        <li><a href="#" class="text-white"><i class="bi bi-envelope"></i> Contact</a></li>
                    </ul>
                </div>
            </div>
            <hr class="mt-4 bg-light">
            <div class="text-center">
                <p class="mb-0">&copy; 2023 SecureScan. All rights reserved.</p>
            </div>
        </div>
    </footer>

    <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0/dist/js/bootstrap.bundle.min.js"></script>
    <script>
        // Smooth scrolling for anchor links
        document.querySelectorAll('a[href^="#"]').forEach(anchor => {
            anchor.addEventListener('click', function (e) {
                e.preventDefault();
                document.querySelector(this.getAttribute('href')).scrollIntoView({
                    behavior: 'smooth'
                });
            });
        });
    </script>
</body>
</html>
"""

# Enhanced result processing
def check_url_for_web(url):
    features = extract_features(url)
    prob = model.predict_proba(features)[0][1]  # Probability of being phishing
    
    # Get top 5 most important features for this prediction
    importances = model.feature_importances_
    top_features_indices = importances.argsort()[-5:][::-1]
    top_features = [
        {
            'name': X_train.columns[i],
            'value': str(features.iloc[0][X_train.columns[i]]),
            'safe': features.iloc[0][X_train.columns[i]] < importances.mean()
        }
        for i in top_features_indices
    ]
    
    if prob > 0.6:  # Threshold for phishing
        return {
            'url': url,
            'is_safe': False,
            'status': '⚠️ Phishing Detected!',
            'confidence': f"{prob*100:.1f}",
            'details': 'This URL shows multiple characteristics of a phishing attempt. Do not enter any personal information.',
            'key_features': top_features
        }
    else:
        return {
            'url': url,
            'is_safe': True,
            'status': '✅ Safe URL',
            'confidence': f"{(1-prob)*100:.1f}",
            'details': 'This URL appears to be safe based on our analysis.',
            'key_features': top_features
        }

@app.route('/', methods=['GET', 'POST'])
def home():
    if request.method == 'POST':
        url = request.form['url']
        result = check_url_for_web(url)
        return render_template_string(HTML_TEMPLATE, result=result)
    return render_template_string(HTML_TEMPLATE, result=None)

def run_flask_app():
    app.run(host='0.0.0.0', port=5000, debug=False, use_reloader=False)

# Start Flask in a separate thread
thread = threading.Thread(target=run_flask_app)
thread.daemon = True
thread.start()

# Display a clickable link in Jupyter
display(HTML("<h3>Flask app is running! <a href='http://localhost:5000' target='_blank'>Open Interface</a></h3>"))
# Out:
# <h3>Flask app is running! <a href='http://localhost:5000' target='_blank'>Open Interface</a></h3>
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.31.52:5000
# Press CTRL+C to quit

# %%
# Your existing imports
import pandas as pd
import re
import tldextract
from urllib.parse import urlparse
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Your existing model training code
# (This should be the same as what you already have)
model = RandomForestClassifier(
    n_estimators=150,
    max_depth=20,
    min_samples_split=5,
    class_weight="balanced",
    random_state=42
)
model.fit(X_train, y_train)

# Your existing feature extraction function
def extract_features(url):
    parsed = urlparse(url)
    ext = tldextract.extract(url)
    hostname = parsed.hostname or ''
    path = parsed.path or ''
    
    features = {
        'length_url': len(url),
        'length_hostname': len(hostname),
        'ip': int(bool(re.match(r'^(\\d+\\.){3}\\d+$', hostname))),
        'nb_dots': url.count('.'),
        'nb_hyphens': url.count('-'),
        'nb_at': url.count('@'),
        'nb_qm': url.count('?'),
        'nb_and': url.count('&'),
        'nb_eq': url.count('='),
        'nb_underscore': url.count('_'),
        'nb_slash': url.count('/'),
        'nb_colon': url.count(':'),
        'nb_comma': url.count(','),
        'nb_semicolumn': url.count(';'),
        'nb_dollar': url.count('$'),
        'nb_space': url.count(' '),
        'nb_www': url.lower().count('www'),
        'nb_com': url.lower().count('.com'),
        'nb_dslash': url.count('//'),
        'http_in_path': int('http' in path),
        'https_token': int('https' in url.lower() and not url.lower().startswith('https://')),
        'ratio_digits_url': sum(c.isdigit() for c in url) / max(len(url), 1),
        'ratio_digits_host': sum(c.isdigit() for c in hostname) / max(len(hostname), 1),
        'tld_in_path': int(ext.suffix and ext.suffix in path),
        'tld_in_subdomain': int(ext.suffix and ext.suffix in ext.subdomain),
        'nb_subdomains': len(ext.subdomain.split('.')),
        'prefix_suffix': int('-' in ext.domain),
        'shortening_service': int(any(s in url for s in ['bit.ly', 'goo.gl', 'tinyurl.com'])),
        'longest_word_host': max((len(w) for w in re.split(r'\\W+', hostname) if w), default=0),
        'avg_word_host': sum(len(w) for w in re.split(r'\\W+', hostname) if w) / max(len(re.split(r'\\W+', hostname)), 1),
        'phish_hints': int(any(w in url.lower() for w in ['login', 'secure', 'account', 'verify', 'update']))
    }
    
    # Create DataFrame with same columns as training data
    features_df = pd.DataFrame(columns=X_train.columns)
    for col in features_df.columns:
        features_df[col] = [features.get(col, 0)]  # Use 0 as default for missing features
    
    return features_df
# Out:
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.31.52:5000
# Press CTRL+C to quit
